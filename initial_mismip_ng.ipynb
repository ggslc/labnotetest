# %% [markdown]
# # MISMIP+ experiments

# %% [markdown]
# The MISMIP+ expriments are to be designed by me (S L Cornford), Hilmar (Gudmundsson), with approval from Frank Pattyn and Gael Durand. We agreed at EGU 2014 and IGS 2014 to base the expriments on Hilmar's channel geoemtry in TC 2012 vol 6(p 1497) http://www.the-cryosphere.net/6/1497/2012/.
#
# The topography $r$ has retrograde and prograde slopes and steep channel walls, and the channel width $w_c$ is a natural parameter to vary in steady-state expriments of the sort described in Hilmar's paper.
#
# $r = B_x(x) + B_y(y)$
#
# where
#
# $B_x(\tilde{x}) = B_0 - 2184.8 \tilde{x}^2 + 1031.72 \tilde{x}^4 - 151.72 \tilde{x}^6$
#
# where
#
# $\tilde{x} = x / 750 {\rm km}$, $0 < x < 1800 {\rm km}$, $0 < y < 240 {\rm km}$
#
# $B_y = d_c / (1 + \exp(-2(y-w_c)/f_c) + d_c / (1 + \exp(2(y-w_c)/f_c)$
#
# Both Ua and Elmer/Ice carried out the steady state experiment and found a stable equilibium on a retrograde slope in the channel (for narrow channels)
#
# For the MISMIP+ experiments, we want to study melt perturbations, so one channel width should be adequate. The parameters $B_0 = 300.0, f_c = 500 {\rm km},  d_c = 1.0{\rm km}, w_c = 40 {\rm km}$ give us a channel 80 km wide

# %% [markdown]
# ## BISICLES implementation

# %% [markdown]
# -Put problem in BISICLES/examples/MISMIPNG
#
# -Used python interface to provide topography etc

# %%
#snippet from ghgChannel.py

import math as m

Bo = 300.0
fc = 5.0e+3
dc = 1.0e+3
wc = 40.0e+3

def Bx(x):
    xx = x/750.0e3
    xx2 = xx*xx
    xx4 = xx2*xx2
    xx6 = xx4*xx2
    return Bo - 2184.8 * xx2 + 1031.72 * xx4 - 151.72 * xx6 

def By(y):
    return dc/(1.0+m.exp(-2.0*(y-wc)/fc)) + dc/(1.0+m.exp(2.0*(y+wc)/fc))

def topography(x,y):
    y = y - 120e+3
    topography = Bx(x) + By(y)
    
    return topography

# %%
#plot the topography
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

dx = 10.0e+3
x = np.arange(0.0+dx/2,1500.0e+3 ,dx)
y = np.arange(0.0 + dx/2,240.0e+3 ,dx)
r = np.zeros([len(y),len(x)])


for i in range(0,len(x)):
    for j in range(0,len(y)):
        r[j,i] = topography(x[i],y[j])
        
plt.figure()
plt.contour(x,y,r,60)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x6bb9ea8>

# %%
#other parts of ghgChannel.py
def thickness(x,y):
    thickness = 0.0
  
    if (x < 1800.0e+3):
        thickness = 100.0
        
    return thickness

def topography(x,y):
    y = y - 120e+3
    topography = Bx(x) + By(y)
    
    return topography


def accumulation(x,y,t,thck,topg):
    acc = 0.3
    if (x > 1800e+3):
        acc = -1000.0
    return acc

def friction(x,y,t,thck,topg):
    friction = 24133.38
    return friction

# %% [markdown]
# <h3>Spinup</h3>
#
# Using amr_velocity_solve_interval > 1 to spinup 3,4,5 lev cases (improves speed, is a little more fragile)
#
# Spinup not finished by Fri 22 Aug (but continuing).

# %%
from amrfile import io as amrio
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as col


def addgl(figure,filename,lev,scale,color):
    rhoi=900.0
    rhoo=1000.0
    amr = amrio.load(filename)
    lo,hi = amrio.queryDomainCorners(amr,lev)
    x,y,h = amrio.readBox2D(amr,lev,lo,hi,'thickness',1)
    x,y,r = amrio.readBox2D(amr,lev,lo,hi,'Z_base',1)
    hab = h + rhoo / rhoi * r
    
    time = amrio.queryTime(amr)
    amrio.free(amr)
    plt.contour(x/scale,y/scale,hab, [0], fig=figure ,colors=color)
    print 'time = ',time,' lev = ',lev
    
    
    

def addfl(figure,filename,lev,scale,color):
    rhoi=900.0
    rhoo=1000.0
    amr = amrio.load(filename)
    lo,hi = amrio.queryDomainCorners(amr,lev)
    lo[1] = (hi[1]+1) / 2
    hi[1] = lo[1]+1
    
    x,y,s = amrio.readBox2D(amr,lev,lo,hi,'Z_surface',0)
    x,y,b = amrio.readBox2D(amr,lev,lo,hi,'Z_bottom',0)
    x,y,r = amrio.readBox2D(amr,lev,lo,hi,'Z_base',0)
    
    
    time = amrio.queryTime(amr)
    amrio.free(amr)
    plt.plot(x/scale, s[0,:],color=color)
    plt.plot(x/scale, b[0,:],color=color)
    plt.plot(x/scale, r[0,:],color=color)
    print 'time = ',time,' lev = ',lev
    

#amrio.freeAll()    
    
f = plt.figure()
scale = 1.0e+3
lev=5

addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.5lev.Chombo.094000.2d.hdf5',lev,scale,'red')

addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.5lev.Chombo.104000.2d.hdf5',lev,scale,'pink')

addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.5lev.Chombo.114000.2d.hdf5',lev,scale,'purple')

addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.5lev.Chombo.124000.2d.hdf5',lev,scale,'orange')


plt.axis([1150,1180,-1200,500])
# Out:
# time =  17924.5  lev =  5
# time =
#  18237.0  lev =  5
# time =
#  18549.5  lev =  5
# time =
#  18861.984375  lev =  5
# [1150, 1180, -1200, 500]

# %%
f = plt.figure()
scale = 1.0e+3
lev=5

lev=5
addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.5lev.Chombo.124000.2d.hdf5',lev,scale,'red')

lev=4
addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.4lev.Chombo.101900.2d.hdf5',lev,scale,'pink')

lev=3
addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.3lev.Chombo.066300.2d.hdf5',lev,scale,'purple')

lev=2
addfl(f,'data/MISMIPNG/spinup/plot.ghgChannel.l1l2.2lev.Chombo.050700.2d.hdf5',lev,scale,'blue')

lev=1
addfl(f,'data/MISMIPNG/spinup/plot.ghgChannel.l1l2.1lev.Chombo.062300.2d.hdf5',lev,scale,'orange')
lev=0
addfl(f,'data/MISMIPNG/spinup/plot.ghgChannel.l1l2.0lev.Chombo.088000.2d.hdf5',lev,scale,'green')
plt.axis([1100,1200,-2000,2000])
# Out:
# time =  18861.984375  lev =  5
# time =
#  20180.75  lev =  4
# time =
#  20408.375  lev =  3
# time =  20003.875  lev =  2
# time =
#  26074.125  lev =  1
# time =  49937.5  lev =  0
# [1100, 1200, -2000, 2000]

# %% [markdown]
# Not sure about convergence here - gl has nearly stopped, but 5 level GL (red) is upstream from 4, depsite aal the rest looking sitting on order : 0(green),1(orange),2(blue),3(purple),4(pink). 5 lev _is_ at an earlier time than the rest. Running an extra expt, lazyspinup2, where I start level 5 from a later level 4 run (100000).

# %%
f = plt.figure()
scale = 1.0e+3

lev=4
addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.4lev.Chombo.100000.2d.hdf5',lev,scale,'blue')

lev=5
addfl(f,'data/MISMIPNG/lazyspinup2/plot.ghgChannel.l1l2.5lev.Chombo.101700.2d.hdf5',lev,scale,'red')

plt.axis([1000,1300,-2000,2000])

f = plt.figure()

lev=4
addgl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.l1l2.4lev.Chombo.100000.2d.hdf5',lev,scale,'blue')

lev=5
addgl(f,'data/MISMIPNG/lazyspinup2/plot.ghgChannel.l1l2.5lev.Chombo.101700.2d.hdf5',lev,scale,'red')

plt.axis([1100,1340,0,240])
# Out:
# time =  20062.0  lev =  4
# time =
#  20115.125  lev =  5
# time =
#  20062.0  lev =  4
# time =
#  20115.125  lev =  5
# [1100, 1340, 0, 240]

# %%
f = plt.figure()
scale = 1.0e+3

lev=5
addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.ssa.5lev.Chombo.097900.2d.hdf5',lev,scale,'red')
lev=4
addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.ssa.4lev.Chombo.077100.2d.hdf5',lev,scale,'pink')

lev=3
addfl(f,'data/MISMIPNG/lazyspinup/plot.ghgChannel.ssa.3lev.Chombo.044900.2d.hdf5',lev,scale,'purple')

lev=2
addfl(f,'data/MISMIPNG/spinup/plot.ghgChannel.ssa.2lev.Chombo.050700.2d.hdf5',lev,scale,'blue')

lev=1
addfl(f,'data/MISMIPNG/spinup/plot.ghgChannel.ssa.1lev.Chombo.062300.2d.hdf5',lev,scale,'orange')
lev=0
addfl(f,'data/MISMIPNG/spinup/plot.ghgChannel.ssa.0lev.Chombo.088000.2d.hdf5',lev,scale,'green')

plt.axis([1000,1300,-2000,2000])
# Out:
# time =  17441.7773438  lev =  5
# time =
#  18630.796875  lev =  4
# time =
#  18299.78125  lev =  3
# time =  20606.0  lev =  2
# time =
#  27052.125  lev =  1
# time =  49937.5  lev =  0
# [1000, 1300, -2000, 2000]

# %% [markdown]
# Melting the ice shelf leads to retreat. I carried out some (premature) perturbations with uniform melt rate 100 m/a (meltx), just to test. The grounding line rtreats by hundreds of km on century scales in both cases

# %%
f = plt.figure()
scale = 1.0e+3

lev=5
addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.l1l2.5lev.Chombo.099900.2d.hdf5',lev,scale,'red')
addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.l1l2.5lev.Chombo.109900.2d.hdf5',lev,scale,'red')
addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.l1l2.5lev.Chombo.119900.2d.hdf5',lev,scale,'red')
addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.l1l2.5lev.Chombo.124200.2d.hdf5',lev,scale,'red')

addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.ssa.5lev.Chombo.089900.2d.hdf5',lev,scale,'blue')
addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.ssa.5lev.Chombo.094900.2d.hdf5',lev,scale,'blue')
addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.ssa.5lev.Chombo.099900.2d.hdf5',lev,scale,'blue')
addfl(f,'data/MISMIPNG/meltx/plot.ghgChannel.ssa.5lev.Chombo.104900.2d.hdf5',lev,scale,'blue')

plt.axis([0,1800,-3000,5000])
# Out:
# time =  18108.875  lev =  5
# time =
#  18154.6777344  lev =  5
# time =
#  18197.4296875  lev =  5
# time =
#  18214.5  lev =  5
# time =
#  17175.6289062  lev =  5
# time =
#  17198.640625  lev =  5
# time =
#  17236.0546875  lev =  5
# time =
#  17275.1171875  lev =  5
# [0, 1800, -3000, 5000]
